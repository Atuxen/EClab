# %%
import eclabfiles as ecf

# import matplotlib.pyplot as plt
from bokeh.plotting import figure, show, output_notebook
from bokeh.palettes import small_palettes, mpl
from bokeh.models import Range1d, LinearAxis
import math
import pandas as pd

# %% [markdown]
# # Potentiostatic Electrochemical Impedance Spectroscopy (PEIS)

# %%
# Folder path for files
PEIS_paths = PEIS_dictionary("./files/PEIS_files/")

PEIS(PEIS_paths)


for key, value in PEIS_paths.items():
    dictionary = {}
    dictionary[key] = value
    PEIS(dictionary)
# Out:
# Check if these are your files of interest {'ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel_01': ['files/PEIS_files/ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel_01_PEIS_C01.mpr'], 'ZnSO4-Molal-2-Coincell-50mikroL-Zn-Steel_03': ['files/PEIS_files/ZnSO4-Molal-2-Coincell-50mikroL-Zn-Steel_03_PEIS_C01.mpr'], 'ZnTFSI2-G4-4-1-Coincell-60mikroL-Zn-Steel_03': ['files/PEIS_files/ZnTFSI2-G4-4-1-Coincell-60mikroL-Zn-Steel_03_PEIS_C06.mpr'], 'ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel-test2_03': ['files/PEIS_files/ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel-test2_03_PEIS_C01.mpr'], 'ZnSO4-Molal-1-Coincell-50mikroL-Zn-Steel_03': ['files/PEIS_files/ZnSO4-Molal-1-Coincell-50mikroL-Zn-Steel_03_PEIS_C06.mpr'], 'ZnSO4-Molal-3-Coincell-50mikroL-Zn-Steel_03': ['files/PEIS_files/ZnSO4-Molal-3-Coincell-50mikroL-Zn-Steel_03_PEIS_C03.mpr'], 'ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel-test2_01': ['files/PEIS_files/ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel-test2_01_PEIS_C01.mpr'], 'ZnSO4-Molal-3-Coincell-50mikroL-Zn-Steel_01': ['files/PEIS_files/ZnSO4-Molal-3-Coincell-50mikroL-Zn-Steel_01_PEIS_C03.mpr'], 'ZnSO4-Molal-1-Coincell-50mikroL-Zn-Steel_01': ['files/PEIS_files/ZnSO4-Molal-1-Coincell-50mikroL-Zn-Steel_01_PEIS_C06.mpr'], 'ZnTFSI2-G4-4-1-Coincell-60mikroL-Zn-Steel_01': ['files/PEIS_files/ZnTFSI2-G4-4-1-Coincell-60mikroL-Zn-Steel_01_PEIS_C06.mpr'], 'ZnSO4-Molal-2-Coincell-50mikroL-Zn-Steel_01': ['files/PEIS_files/ZnSO4-Molal-2-Coincell-50mikroL-Zn-Steel_01_PEIS_C01.mpr'], 'ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel_03': ['files/PEIS_files/ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel_03_PEIS_C01.mpr']}
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ea73ca67-5f38-4750-958d-2a4e860796cb">Loading BokehJS ...</span>
#     </div>
# Error processing frame: Data frame is empty for ZnSO4-Molal-2-Coincell-50mikroL-Zn-Steel_03
# Error processing frame: Data frame is empty for ZnTFSI2-G4-4-1-Coincell-60mikroL-Zn-Steel_03
# Error processing frame: Data frame is empty for ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel-test2_03
# Error processing frame: Data frame is empty for ZnSO4-Molal-1-Coincell-50mikroL-Zn-Steel_03
# Error processing frame: Data frame is empty for ZnSO4-Molal-3-Coincell-50mikroL-Zn-Steel_03
# /Users/achtu/Library/Python/3.9/lib/python/site-packages/eclabfiles/mpr.py:711: UserWarning: No log present in file. Data will not contain absolute time.
#   warnings.warn("No log present in file. Data will not contain absolute time.")
#   <div id="c4d2b528-12f6-4276-b55b-8030bdf43049" data-root-id="p1434" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fadacdc7-8d1b-4bf1-a786-027e06d7d0f5">Loading BokehJS ...</span>
#     </div>
#   <div id="edf06232-3efb-4f2e-be54-345f90d3fe05" data-root-id="p1552" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b85f1d21-5988-443a-bf15-5766e04b7ef8">Loading BokehJS ...</span>
#     </div>
# /var/folders/fr/s1wl518j42d0chw5112zh11h0000z9/T/ipykernel_45969/125748655.py:54: UserWarning:
# You are attempting to set `plot.legend.location` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   pe.legend.location = "top_left"
# /var/folders/fr/s1wl518j42d0chw5112zh11h0000z9/T/ipykernel_45969/125748655.py:55: UserWarning:
# You are attempting to set `plot.legend.title` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   pe.legend.title = "ZnSO4 Concentrations"
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1598', ...)
# Error processing frame: Data frame is empty for ZnSO4-Molal-2-Coincell-50mikroL-Zn-Steel_03
#   <div id="e2c88147-285f-4ba9-aa84-36f7ca664690" data-root-id="p1598" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cfaa2375-ebb1-4d0c-a509-bf080658abca">Loading BokehJS ...</span>
#     </div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1631', ...)
# Error processing frame: Data frame is empty for ZnTFSI2-G4-4-1-Coincell-60mikroL-Zn-Steel_03
#   <div id="c0ffd519-45b0-4828-a80a-c5cf2f8ab1d3" data-root-id="p1631" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e0077e26-f7da-4c04-bc38-5b4eb2deb106">Loading BokehJS ...</span>
#     </div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1664', ...)
# Error processing frame: Data frame is empty for ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel-test2_03
#   <div id="e8451a6f-7f4b-439d-8365-30dc8200e02d" data-root-id="p1664" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b6206c06-5f08-490c-bce9-c8bbb90cde92">Loading BokehJS ...</span>
#     </div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1697', ...)
# Error processing frame: Data frame is empty for ZnSO4-Molal-1-Coincell-50mikroL-Zn-Steel_03
#   <div id="e2db6dca-1112-4e12-b8ab-ebc6312138bb" data-root-id="p1697" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d1fc1930-25f9-4453-be38-5d50712d5f69">Loading BokehJS ...</span>
#     </div>
# Error processing frame: Data frame is empty for ZnSO4-Molal-3-Coincell-50mikroL-Zn-Steel_03
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1730', ...)
#   <div id="b6106a1e-9a6d-4b62-bd6a-350549e6ab89" data-root-id="p1730" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cf106d6a-6278-4fbf-8de0-e41520da9e46">Loading BokehJS ...</span>
#     </div>
#   <div id="ffe3a874-a704-45c8-a074-9b3d411b6433" data-root-id="p1763" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f697f88a-6006-4fea-9023-5d7005e6974b">Loading BokehJS ...</span>
#     </div>
#   <div id="c476e520-59ce-41e6-9654-b0a8258fe6e5" data-root-id="p1809" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a24c7388-11a7-4f18-8727-5d6e00c58cb7">Loading BokehJS ...</span>
#     </div>
#   <div id="efd50b6d-831d-418b-a25f-088d38d68f57" data-root-id="p1855" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d9fdc613-a6fb-4b68-ad5e-8b97ef4acd4d">Loading BokehJS ...</span>
#     </div>
#   <div id="be7f1e9e-7192-481f-bd7f-79839aaa5e5a" data-root-id="p1901" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ac3d8d6a-a83e-4169-a3ce-4fefe5c0bfa6">Loading BokehJS ...</span>
#     </div>
#   <div id="cbd09c51-9469-4a77-9942-8a9aa37e2af3" data-root-id="p1947" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ebada46d-96ab-4014-88d9-14bc15e47d54">Loading BokehJS ...</span>
#     </div>
#   <div id="ef816185-df94-4b66-8902-49dce74999f3" data-root-id="p1993" style="display: contents;"></div>

# %% [markdown]
# # Fuctions and libs (Run these first)

# %%
from bokeh.io import output_notebook, show
from bokeh.layouts import row
from bokeh.plotting import figure

# import pandas as pd

df = ecf.to_df(
    "./ZnTFSI2 characterization/ZnTFSI2-G4-1-5-Coincell-60mikroL-Zn-Steel_01_PEIS_C01.mpr"
)
print(df.columns)

potential = df["<Ewe>"]
time = df["time"]

zReal = df["Re(Z)"]
zImagine = df["-Im(Z)"]


output_notebook()

nyquist_plot = figure(
    title="Nyquist Plot",
    x_axis_label="Z' (Ω)",
    y_axis_label="-Z'' (Ω)",
    width=400,
    height=300,
)
nyquist_plot.line(
    zReal, zImagine, legend_label="Nyquist Curve", line_color="blue", line_width=2
)

e_vs_i_plot = figure(
    title="Ewe vs. Time Plot",
    x_axis_label="Time (h)",
    y_axis_label="Ewe (V)",
    width=400,
    height=300,
)
e_vs_i_plot.line(
    time,
    potential,
    legend_label="E vs. Time",
    line_color="red",
    line_width=2,
    line_dash="dashed",
)

layout = row(nyquist_plot, e_vs_i_plot)
show(layout)
# Out:
# Index(['freq', 'Re(Z)', '-Im(Z)', '|Z|', 'Phase(Z)', 'time', '<Ewe>', '<I>',
#        'Cs', 'Cp', 'cycle number', 'I Range', '|Ewe|', '|I|', '(Q-Qo)', 'uts'],
#       dtype='object')
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f9fdffd4-e2be-42b7-9738-44fb8c51c879">Loading BokehJS ...</span>
#     </div>
#   <div id="e50f7617-67db-4abb-bcb5-80fcd33f0179" data-root-id="p1089" style="display: contents;"></div>

# %%
from bokeh.palettes import small_palettes


class DataFrameEmpty(Exception):
    pass


def PEIS(dict):

    output_notebook()
    pe = figure(
        title="Nyquist plot",
        x_axis_label="Real values Z' (Ω)",
        y_axis_label="Imagineary values Z'' (Ω)",
        width=800,
        height=400,
    )

    ## Constrain axes
    # pe.x_range.start = -0.5  # Set x-axis range from 0 to 3V
    # pe.x_range.end = 4
    # pe.y_range.start = -20  # Set y-axis range from 0 to 20 mA/cm^2
    # pe.y_range.end = 20

    color = 0
    for key, value in dict.items():
        try:
            df = ecf.to_df(value[0])
            if df.empty:
                raise DataFrameEmpty(f"Data frame is empty for {key}")

        except DataFrameEmpty as eD:
            print(f"Error processing frame: {eD}")
            continue
        except Exception as e:
            print(f"Error processing {key}: {e}")


        zReal = df["Re(Z)"]
        zImagine = df["-Im(Z)"]

        # Plot
        colors = small_palettes["Viridis"][4]
        pe.line(
            zReal,
            zImagine,
            legend_label=key,
            line_color=colors[color % len(colors)],
            line_width=1,
        )

        color += 1

    pe.legend.location = "top_left"
    pe.legend.title = "ZnSO4 Concentrations"
    show(pe)

# %%
# Cycling dictionary maker
from pathlib import Path


def PEIS_dictionary(path):
    folder_path = Path(path)
    data_dict = {}

    # Iterate over all .mpr files that contain "LSV"
    for file_path in folder_path.iterdir():
        if (
            file_path.is_file()
            and file_path.suffix == ".mpr"
            and "PEIS" in file_path.name
        ):
            # Find the position of "GCLP"
            file_name = file_path.name
            peis_index = file_name.find("PEIS")

            # Extract 4 characters before "LSV"
            if peis_index > 1:  # Ensure there are at least 4 characters before
                prefix = file_name[: peis_index - 1]
                # print(f"Prefix before 'LSV': {prefix}")
            else:
                print(f"Not enough characters before 'CV' in {file_name}")
                prefix = "InvalidPrefix"

            # Add the file name to the dictionary under the appropriate prefix
            if prefix not in data_dict:
                data_dict[prefix] = [str(file_path)]

    print(f"Check if these are your files of interest {data_dict}")

    return data_dict
